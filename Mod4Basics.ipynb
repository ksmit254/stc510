# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import getpass
from time import sleep

# %%
url = 'https://phoenix.craigslist.org/search/gms'

response = requests.get(url)

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    \n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1">\n\t<meta property="og:site_name" content="craigslist">\n\t<meta name="twitter:card" content="preview">\n\t<meta property="og:title" content="phoenix garage &amp; moving sales - craigslist">\n\t<meta name="description" content="phoenix garage &amp; moving sales - craigslist">\n\t<meta property="og:description" content="phoenix garage &amp; moving sales - craigslist">\n\t<meta property="og:url" content="https://phoenix.craigslist.org/search/gms">\n\t<title>phoenix garage &amp; moving sales - craigslist</title>\n\t<link rel="canonical" href="https://phoenix.craigslist.org/search/gms">\n\n\n\n<script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"phoenix.craigslist.org","@id":"https://phoenix.craigslist.org"},"position
# ...

# %%
webpage = BeautifulSoup(response.content, 'lxml')

# %%
rows = webpage.find(class_='rows')
print("Number of row tags: %s" % (len(rows)))
rows
# Out:
# Number of row tags: 339
# <ul class="rows" id="search-results">
# <h4 class="ban"><span class="bantext">sales on tue feb  8</span></h4>
# <li class="result-row" data-pid="7438010944">
# <a class="result-image gallery" data-ids="3:00x0x_kZkqEmNyi06z_0CI0sC,3:00Y0Y_d6UvexPK1H2z_0in0t2,3:00g0g_gEO0mZ9tjZmz_0pD0t2,3:00T0T_48JVifwnfl0z_0CI0t2,3:00y0y_91S9TPPF6gGz_0CI0t2,3:00H0H_j1WrktCv3yqz_0t20CI,3:00l0l_3oakVZj4555z_0t20CI,3:00U0U_89DRPElL0gJz_0t20CI,3:00b0b_8jK8foBzTtCz_0t20CI,3:00t0t_hgj3yEIDdWWz_0t20CI,3:00E0E_7ktWovTKo7tz_0t20CI,3:00p0p_fsHck2jCfkvz_0lM0t2,3:00H0H_1Exzy9AcKDMz_0t20CI,3:00r0r_8uGAk9j5Rtfz_0t20CI" href="https://phoenix.craigslist.org/evl/gms/d/san-tan-valley-lot-of-great-things-all/7438010944.html">
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <h3 class="result-heading">
# ...

# %%
dir(rows)
row = rows.find(class_='result-row')

# %%
row.find(class_='result-title hdrlnk')
# Out:
# <a class="result-title hdrlnk" data-id="7438010944" href="https://phoenix.craigslist.org/evl/gms/d/san-tan-valley-lot-of-great-things-all/7438010944.html" id="postid_7438010944">Lot of great things all for one price</a>

# %%
rows = webpage.find(class_='rows')
rows = rows.find_all(class_='result-row')
links = []
titles = []

for row in rows:
    post = row.find(class_='result-title hdrlnk')
    title = post.get_text()
    if "tool" in title:
        link = post.get('href')
        print(link)
        print(title)
        results.append(title + ',' + link + ',')
# Out:
# https://phoenix.craigslist.org/evl/gms/d/scottsdale-estate-sale-fri-and-sat/7442962418.html
# Estate sale Fri and Sat. Vintage tools
# https://phoenix.craigslist.org/evl/gms/d/scottsdale-estate-sale-fri-and-sat/7442962418.html
# Estate sale Fri and Sat. Vintage tools
# https://phoenix.craigslist.org/wvl/gms/d/surprise-yard-sale-hand-tools-and/7442288487.html
# Yard Sale - hand tools and houshold items
# https://phoenix.craigslist.org/wvl/gms/d/surprise-yard-sale-hand-tools-and/7442288487.html
# Yard Sale - hand tools and houshold items
# https://tucson.craigslist.org/gms/d/tucson-garden-tools-cheap-moving-soon/7439757806.html
# Garden tools, cheap! Moving soon. Must go - Ideal for Spring planting.
# https://tucson.craigslist.org/gms/d/tucson-moving-sale-everything-but-the/7431573220.html
# Moving sale everything but the tools must go!

# %%
links = []
titles = []

for row in rows:
    post = row.find(class_='result-title hdrlnk')
    title = post.get_text()
    if "tool" in title:
        link = post.get('href')
        print(link)
        print(title)
        titles.append(title + ',')
        links.append(link + ',')
        results.append(title + ',' + link + ',')
# Out:
# https://phoenix.craigslist.org/evl/gms/d/scottsdale-estate-sale-fri-and-sat/7442962418.html
# Estate sale Fri and Sat. Vintage tools
# https://phoenix.craigslist.org/evl/gms/d/scottsdale-estate-sale-fri-and-sat/7442962418.html
# Estate sale Fri and Sat. Vintage tools
# https://phoenix.craigslist.org/wvl/gms/d/surprise-yard-sale-hand-tools-and/7442288487.html
# Yard Sale - hand tools and houshold items
# https://phoenix.craigslist.org/wvl/gms/d/surprise-yard-sale-hand-tools-and/7442288487.html
# Yard Sale - hand tools and houshold items
# https://tucson.craigslist.org/gms/d/tucson-garden-tools-cheap-moving-soon/7439757806.html
# Garden tools, cheap! Moving soon. Must go - Ideal for Spring planting.
# https://tucson.craigslist.org/gms/d/tucson-moving-sale-everything-but-the/7431573220.html
# Moving sale everything but the tools must go!

# %%
links
# Out:
# ['https://phoenix.craigslist.org/evl/gms/d/scottsdale-estate-sale-fri-and-sat/7442962418.html,',
#  'https://phoenix.craigslist.org/evl/gms/d/scottsdale-estate-sale-fri-and-sat/7442962418.html,',
#  'https://phoenix.craigslist.org/wvl/gms/d/surprise-yard-sale-hand-tools-and/7442288487.html,',
#  'https://phoenix.craigslist.org/wvl/gms/d/surprise-yard-sale-hand-tools-and/7442288487.html,',
#  'https://tucson.craigslist.org/gms/d/tucson-garden-tools-cheap-moving-soon/7439757806.html,',
#  'https://tucson.craigslist.org/gms/d/tucson-moving-sale-everything-but-the/7431573220.html,']

# %%
titles
# Out:
# ['Estate sale Fri and Sat. Vintage tools,',
#  'Estate sale Fri and Sat. Vintage tools,',
#  'Yard Sale - hand tools and houshold items,',
#  'Yard Sale - hand tools and houshold items,',
#  'Garden tools, cheap! Moving soon. Must go - Ideal for Spring planting.,',
#  'Moving sale everything but the tools must go!,']

# %%
results = pd.DataFrame(list(zip(titles,links)),columns =['titles','links'])

# %%
results
# Out:
#                                               titles  \
# 0            Estate sale Fri and Sat. Vintage tools,
# 1            Estate sale Fri and Sat. Vintage tools,
# 2         Yard Sale - hand tools and houshold items,
# 3         Yard Sale - hand tools and houshold items,
# 4  Garden tools, cheap! Moving soon. Must go - Id...
# 5     Moving sale everything but the tools must go!,
#
#                                                links
# 0  https://phoenix.craigslist.org/evl/gms/d/scott...
# 1  https://phoenix.craigslist.org/evl/gms/d/scott...
# 2  https://phoenix.craigslist.org/wvl/gms/d/surpr...
# 3  https://phoenix.craigslist.org/wvl/gms/d/surpr...
# 4  https://tucson.craigslist.org/gms/d/tucson-gar...
# 5  https://tucson.craigslist.org/gms/d/tucson-mov...

# %%
results.to_csv('craigslistresults.csv')
